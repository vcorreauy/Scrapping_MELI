# %%
# IMPORTO LIBRERIAS

import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import calendar
import time
from datetime import datetime
from statistics import mean
from matplotlib import pylab
from pylab import *
import re

# %%
# PAGINA DE MELI DE VENTA DE APARTAMENTOS EN MONTEVIDEO

link_busqueda='https://listado.mercadolibre.com.uy/inmuebles/apartamentos/venta/2-dormitorios/montevideo/_FULL*BATHROOMS_2-2_PARKING*LOTS_1-1#applied_filter_id%3Dstate%26applied_filter_name%3DUbicaci%C3%B3n%26applied_filter_order%3D6%26applied_value_id%3DTUxVUE1PTlo2MDIy%26applied_value_name%3DMontevideo%26applied_value_order%3D5%26applied_value_results%3D1387%26is_custom%3Dfalse'

r=requests.get(link_busqueda)
print(r.status_code)
soup= BeautifulSoup(r.content,'html.parser')
# Out:
# 200

# %%
# SELECCIONO LOS DATOS QUE ME INTERESAN Y ARMO VARIABLES

# DIRECCION
direccion=soup.find_all('div', class_='ui-search-item__location-container-grid')
#print(direccion)

direcciones_lista=[]
for i in direccion:
    direcciones=i.get_text().split(",")[0]
    direcciones_lista.append(direcciones)

print(len(direcciones_lista))
print(direcciones_lista[0])
# Out:
# 48
# Pocitos

# %%
# BARRIO
barrio=soup.find_all('div', class_='ui-search-item__location-container-grid')
barrio_lista=[]

for i in barrio:
    #print(len(i))
    barrios=i.get_text().split(", ")
    if len(barrios) >=2:
        barrio_lista.append(barrios[1])
    else:
        barrio_lista.append(" ")

print(len(barrio_lista))
print(barrio_lista[0])
# Out:
# 48
# Montevideo

# %%
# METROS CUADRADOS
cualca=soup.find_all('ul', class_='ui-search-card-attributes ui-search-item__attributes-grid')
cualca_lista=[]
for i in cualca:
    cualca=i.get_text().split(" ")[2]
    cualca=cualca[5:]
    if "," in cualca:
     cualca = cualca.replace(",", ".")
     cualca_lista.append(float(cualca))
    elif cualca is None or not cualca:
     cualca=1
     cualca_lista.append(float(cualca))
    elif not cualca.isdigit():
     cualca =1
     cualca_lista.append(float(cualca))
    else:
    #print(cualca)
     cualca_lista.append(float(cualca))

print(len(cualca_lista))
print(type(cualca_lista[0]))
print(cualca_lista)
# Out:
# 48
# <class 'float'>
# [67.0, 67.0, 66.0, 68.0, 83.0, 90.0, 83.0, 50.0, 80.0, 90.0, 68.0, 74.0, 73.0, 71.0, 77.0, 58.0, 60.0, 65.0, 63.0, 97.0, 66.0, 72.0, 77.0, 69.0, 62.0, 51.0, 62.0, 55.0, 70.0, 75.0, 66.0, 78.0, 85.0, 64.0, 74.0, 67.0, 60.0, 79.0, 56.0, 59.0, 1.0, 103.0, 68.0, 77.0, 74.0, 63.0, 70.0, 65.0]

# %%
# NUMERO DE DORMITORIOS
nro_dorm=soup.find_all('ul', class_='ui-search-card-attributes ui-search-item__attributes-grid')
nro_dorm_lista=[]

for i in nro_dorm:
    nro_dorm=i.get_text().split(" ")[0]
    nro_dorm_lista.append(int(nro_dorm))


print(len(nro_dorm_lista))
print(type(nro_dorm_lista[0]))
print((nro_dorm_lista[0]))
# Out:
# 48
# <class 'int'>
# 2
# '\nfor i in nro_dorm:\n    nro_dorms=i.get_text().split(" ")#[2]\n    if len(nro_dorms) >=3:\n        nro_dorms=nro_dorms[2]\n        numero = nro_dorms[-1]\n        if numero==\'s\':\n            numero=\'Monoambiente\'\n            nro_dorm_lista.append(numero)\n        else:\n            nro_dorm_lista.append(int(numero))\n    else:\n        nro_dorm_lista.append(" ")\n'

# %%
# PRECIO

precio= soup.find_all('div', class_='ui-search-price ui-search-price--size-medium shops__price')
nro_precio=[]
#print(precio)

for i in precio:
    precios=i.get_text().split(" ")#[1]
    if len(precios) >=1:
        precios=precios[0]
        precios=re.findall(r'\D+|\d+',precios)
        if len(precios)>1:
            precios=precios[1]
        else:
            precios=precios[0]
        nro_precio.append((int(float(precios))))
    else:
        nro_precio.append(int(float(precios)))
    #print(precios)



print(len(nro_precio))
print(type(nro_precio[0]))
print(nro_precio[0])
# Out:
# 48
# <class 'int'>
# 200000

# %%
# LINK DE LA PUBLICACION
link_posteo= soup.find_all('a', class_='ui-search-result__image shops__picturesStyles ui-search-link')
link_posteo= [i.get('href') for i in link_posteo]

print(len(link_posteo))
print((link_posteo[0]))
# Out:
# 48
# https://apartamento.mercadolibre.com.uy/MLU-657531734-venta-apartamento-pocitos-2-dormitorios-con-gge-_JM#position=1&search_layout=grid&type=item&tracking_id=40b986d2-4c73-4c54-a89d-2b4dc512a769

# %%
# NRO DE PAGINA INICIAL
#inicio=soup.find('span', class_='andes-pagination__link').text
inicio=soup.find('li', class_='andes-pagination__button andes-pagination__button--current').text
print(inicio)
# Out:
# 1

# %%
# NRO-LINK DE PAGINA SIGUIENTE
siguiente=soup.find_all('a', attrs={"title":"Siguiente"})[0].get('href')
print(siguiente)
# Out:
# https://listado.mercadolibre.com.uy/inmuebles/apartamentos/venta/2-dormitorios/montevideo/_Desde_49_FULL*BATHROOMS_2-2_NoIndex_True_PARKING*LOTS_1-1

# %%
# NRO DE PAGINA FINAL
fin=soup.find('li', class_='andes-pagination__page-count')
fin=int(fin.text.split(" ")[1])
print(fin)
# Out:
# 19

# %%
lista_direcciones=[]
lista_barrios=[]
lista_links=[]
lista_precios=[]
lista_metros_cuad=[]
lista_nro_dorm=[]

# %%
siguiente='https://listado.mercadolibre.com.uy/inmuebles/apartamentos/venta/2-dormitorios/montevideo/_FULL*BATHROOMS_2-2_PARKING*LOTS_1-1#applied_filter_id%3Dstate%26applied_filter_name%3DUbicaci%C3%B3n%26applied_filter_order%3D6%26applied_value_id%3DTUxVUE1PTlo2MDIy%26applied_value_name%3DMontevideo%26applied_value_order%3D5%26applied_value_results%3D1387%26is_custom%3Dfalse'
try:
    while True:

        r=requests.get(siguiente)
        if r.status_code==200:
            soup= BeautifulSoup(r.content,'html.parser')
            # DIRECCION
            direccion=soup.find_all('div', class_='ui-search-item__location-container-grid')
            #direcciones_lista=[]
            for i in direccion:
              direcciones=i.get_text().split(",")[0]
              lista_direcciones.append(direcciones)

            # BARRIO
            barrio=soup.find_all('div', class_='ui-search-item__location-container-grid')
            #barrio_lista=[]
            for i in barrio:
              barrios=i.get_text().split(", ")
              if len(barrios) >=2:
                lista_barrios.append(barrios[1])
              else:
                lista_barrios.append(" ")

            # LINK
            link_posteo= soup.find_all('a', class_='ui-search-result__image shops__picturesStyles ui-search-link')
            link_posteo= [i.get('href') for i in link_posteo]
            lista_links.extend(link_posteo)

            # PRECIO
            precio= soup.find_all('div', class_='ui-search-price ui-search-price--size-medium shops__price')
            for i in precio:
                precios=i.get_text().split(" ")#[1]
                if len(precios) >=1:
                    precios=precios[0]
                    precios=re.findall(r'\D+|\d+',precios)
                    if len(precios)>1:
                        precios=precios[1]
                    else:
                        precios=precios[0]
                    lista_precios.append((int(float(precios))))

                else:
                    lista_precios.append(int(float("0.0")))


            # METROS CUADRADOS
            cualca=soup.find_all('ul', class_='ui-search-card-attributes ui-search-item__attributes-grid')
            for i in cualca:
             cualca=i.get_text().split(" ")[2]
             cualca=cualca[5:]
             if "," in cualca:
              cualca = cualca.replace(",", ".")
              lista_metros_cuad.append(float(cualca))
             elif cualca is None or not cualca:
              cualca=1
              lista_metros_cuad.append(float(cualca))
             elif not cualca.isdigit():
              cualca =1
              lista_metros_cuad.append(float(cualca))
             else:
              #print(cualca)
              lista_metros_cuad.append(float(cualca))




            # NUMERO DE DORMITORIOS
            nro_dorm=soup.find_all('ul', class_='ui-search-card-attributes ui-search-item__attributes-grid')
            #nro_dorm_lista=[]

            for i in nro_dorm:
             nro_dorm=i.get_text().split(" ")[0]
             lista_nro_dorm.append(int(nro_dorm))



            #validar inicio y fin
            inicio=soup.find('span', class_='andes-pagination__link').text
            fin=soup.find('li', class_='andes-pagination__page-count')
            fin=int(fin.text.split(" ")[1])

        else:
            break

        print(inicio, fin)
        print(len(lista_direcciones),len(lista_barrios),len(lista_links),len(lista_precios),len(lista_metros_cuad),len(lista_nro_dorm))
        if inicio==fin:
            break
        #siguiente= soup.find_all('a', attrs={"class":'andes-pagination__link ui-search-link', "title":"siguiente"})[0].get('href')
        siguiente=soup.find_all('a', attrs={"title":"Siguiente"})[0].get('href')
except IndexError:
        pass
# Out:
# 1 19
# 48 48 48 48 48 48
# 2 19
# 96 96 96 96 96 96
# 3 19
# 144 144 144 144 144 144
# 4 19
# 192 192 192 192 192 192
# 5 19
# 240 240 240 240 240 240
# 6 19
# 288 288 288 288 288 288
# 7 19
# 336 336 336 336 336 336
# 8 19
# 384 384 384 384 384 384
# 9 19
# 432 432 432 432 432 432
# 10 19
# 480 480 480 480 480 480
# 11 19
# 528 528 528 528 528 528
# 12 19
# 576 576 576 576 576 576
# 13 19
# 624 624 624 624 624 624
# 14 19
# 672 672 672 672 672 672
# 15 19
# 720 720 720 720 720 720
# 16 19
# 768 768 768 768 768 768
# 17 19
# 816 816 816 816 816 816
# 18 19
# 864 864 864 864 864 864
# 19 19
# 882 882 882 882 882 882

# %%
print(type(lista_precios[7]))
print(type(lista_metros_cuad[7]))
print(((lista_precios[7])))
print((lista_metros_cuad[0:5]))
# Out:
# <class 'int'>
# <class 'float'>
# 145000
# [67.0, 67.0, 66.0, 68.0, 83.0]

# %%
# PRECIO MT2
precio_mt2 = [(x/y) for x, y in zip(lista_precios, lista_metros_cuad) if x is not None and y is not None and y != 0]

precio_mt2 = [round(y) for y in precio_mt2]

for i in precio_mt2:
 if i==" ":
  i=0
  precio_mt2.append(i)

print(len(precio_mt2))
# Out:
# 882

# %%
# Creamos DF
a={'Barrio':lista_barrios,'Direccion':lista_direcciones,'Mts2':lista_metros_cuad,'Nro Dorm':lista_nro_dorm,'Precio USD':lista_precios,'Precio Mt2':precio_mt2,'Link':lista_links}
df=pd.DataFrame(a, index=list(range(1,len(lista_direcciones)+1)))
df.sort_values(by=['Precio Mt2'], ascending=True)
# Out:
#                           Barrio             Direccion   Mts2  Nro Dorm  \
# 812  Montevideo Departamento ...              Carrasco  101.0         2
# 655               Villa Española         Arribeños  Sn   55.0         2
# 379                       Centro  Canelones Esq. Ejido   97.0         2
# 226                   Montevideo                Centro   87.0         2
# 67        Montevideo Departam...         Paysandú 1222   87.0         2
# ..                           ...                   ...    ...       ...
# 473                        Buceo       Diamantis Plaza    1.0         2
# 643               Punta Carretas           Ellauri 560    1.0         2
# 660               Punta Carretas         Punta Carreta    1.0         2
# 650                   Montevideo               Pocitos    1.0         2
# 561                 Puerto Buceo      Puerto Del Buceo    1.0         2
#
#      Precio USD  Precio Mt2                                               Link
# 812      118000        1168  https://apartamento.mercadolibre.com.uy/MLU-63...
# 655       70000        1273  https://apartamento.mercadolibre.com.uy/MLU-63...
# 379      128000        1320  https://apartamento.mercadolibre.com.uy/MLU-65...
# 226      139000        1598  https://apartamento.mercadolibre.com.uy/MLU-65...
# 67       144000        1655  https://apartamento.mercadolibre.com.uy/MLU-65...
# ..          ...         ...                                                ...
# 473      330000      330000  https://apartamento.mercadolibre.com.uy/MLU-63...
# 643      335000      335000  https://apartamento.mercadolibre.com.uy/MLU-65...
# 660      379000      379000  https://apartamento.mercadolibre.com.uy/MLU-65...
# 650      510000      510000  https://apartamento.mercadolibre.com.uy/MLU-65...
# 561      520000      520000  https://apartamento.mercadolibre.com.uy/MLU-65...
#
# [882 rows x 7 columns]

# %%
# Hacemos algunos cambios para no tener problemas con simbolos y letras
df = df.replace('í','i', regex=True)
df = df.replace('ó','o', regex=True)
df = df.replace('é','e', regex=True)
df = df.replace('á','a', regex=True)
df = df.replace('Á','a', regex=True)
df = df.replace('ú','u', regex=True)
df = df.replace('ñ','n', regex=True)
#print(df)

# %%
# Guardamos DF en un csv o excel
nombre_file=f"venta_apartamentos_montevideo_meli.xlsx"

df.to_excel(nombre_file,index=False)

# %%
# PARA DESCARGAR EL ARCHIVO GENERADO
from google.colab import files
files.download(nombre_file)

# %%
# Para ver toda la info completa de todas las columnas
pd.set_option('display.max_colwidth', None)

# %%
df
# Out:
#             Barrio                         Direccion  Mts2  Nro Dorm  \
# 1       Montevideo                           Pocitos  67.0         2
# 2       Montevideo                     Parque Batlle  67.0         2
# 3       Montevideo                           Pocitos  66.0         2
# 4           Malvin                            Malvin  68.0         2
# 5      Carrasco...          Rbla Republica De Mexico  83.0         2
# ..             ...                               ...   ...       ...
# 878        Pocitos                         Rivera Sn  71.0         2
# 879        Pocitos                     Paysandu 1242  82.0         2
# 880            ...  Rambla Concepcion Del Uruguay Sn  65.0         2
# 881  Pocitos Nuevo                    Marco Bruto Sn  65.0         2
# 882         113...     Rbla. Republica Del Peru 1383  80.0         2
#
#      Precio USD  Precio Mt2  \
# 1        200000        2985
# 2        200000        2985
# 3        239000        3621
# 4        235000        3456
# 5        450000        5422
# ..          ...         ...
# 878      249000        3507
# 879      260000        3171
# 880      249000        3831
# 881      264000        4062
# 882      280000        3500
#
#                                                                                                                                                                                                                                           Link
# 1                                           https://apartamento.mercadolibre.com.uy/MLU-657531734-venta-apartamento-pocitos-2-dormitorios-con-gge-_JM#position=1&search_layout=grid&type=item&tracking_id=61032ebe-0bdb-42e5-bce7-ca1aa1b2b448
# 2                                     https://apartamento.mercadolibre.com.uy/MLU-657492832-venta-apartamento-parque-batlle-2-dormitorios-con-gge-_JM#position=2&search_layout=grid&type=item&tracking_id=61032ebe-0bdb-42e5-bce7-ca1aa1b2b448
# 3                                                  https://apartamento.mercadolibre.com.uy/MLU-633637651-venta-apto-2-dorm-garaje-sobre-av-brasil-_JM#position=3&search_layout=grid&type=item&tracking_id=61032ebe-0bdb-42e5-bce7-ca1aa1b2b448
# 4                                                                     https://apartamento.mercadolibre.com.uy/MLU-633624513-apartamento-en-malvin-_JM#position=4&search_layout=grid&type=item&tracking_id=61032ebe-0bdb-42e5-bce7-ca1aa1b2b448
# 5                         https://apartamento.mercadolibre.com.uy/MLU-657506440-venta-departamento-2-dormitorios-piscina-barbacoa-rambla-carrasco-_JM#position=5&search_layout=grid&type=item&tracking_id=61032ebe-0bdb-42e5-bce7-ca1aa1b2b448
# ..                                                                                                                                                                                                                                         ...
# 878                                         https://apartamento.mercadolibre.com.uy/MLU-655699302-2dorm-con-patio-2-banos-garaje-seguridad-24-hs-_JM#position=14&search_layout=grid&type=item&tracking_id=bb5fe328-7e3a-46f9-8e39-dcd512ca119b
# 879                                                     https://apartamento.mercadolibre.com.uy/MLU-656020724-casa-de-dos-dormitorios-en-pocitos-_JM#position=15&search_layout=grid&type=item&tracking_id=bb5fe328-7e3a-46f9-8e39-dcd512ca119b
# 880                              https://apartamento.mercadolibre.com.uy/MLU-633341301-apto-pta-baja-con-vista-al-mar-2-dorm-2-banos-patio-y-gge-_JM#position=16&search_layout=grid&type=item&tracking_id=bb5fe328-7e3a-46f9-8e39-dcd512ca119b
# 881                               https://apartamento.mercadolibre.com.uy/MLU-656220302-vendo-apartamento-a-estrenar-en-la-mejor-zona-de-pocitos-_JM#position=17&search_layout=grid&type=item&tracking_id=bb5fe328-7e3a-46f9-8e39-dcd512ca119b
# 882  https://apartamento.mercadolibre.com.uy/MLU-656767908-dueno-vende-precioso-apartamento-con-excelente-vista-al-mar-solo-interesados-directos-_JM#position=18&search_layout=grid&type=item&tracking_id=bb5fe328-7e3a-46f9-8e39-dcd512ca119b
#
# [882 rows x 7 columns]

# %%
# CALCULOS

# %%
# Summary
df.describe()
# Out:
#              Mts2  Nro Dorm    Precio USD     Precio Mt2
# count  882.000000     882.0  8.820000e+02     882.000000
# mean    77.513251       2.0  3.038941e+05    9391.184807
# std     21.121844       0.0  1.029577e+05   40949.982336
# min      1.000000       2.0  7.000000e+04    1168.000000
# 25%     66.000000       2.0  2.402750e+05    3300.000000
# 50%     75.000000       2.0  2.880000e+05    3794.000000
# 75%     87.000000       2.0  3.380000e+05    4342.000000
# max    184.000000       2.0  1.060000e+06  520000.000000

# %%
# Precio promedio mt2
mt2_prom=round(df["Precio Mt2"].mean())
print(mt2_prom)
# Out:
# 9391

# %%
# APTO CON EL MT2 MAS CARO
df[df['Precio Mt2'] >= max(df['Precio Mt2'])]
# Out:
#            Barrio         Direccion  Mts2  Nro Dorm  Precio USD  Precio Mt2  \
# 561  Puerto Buceo  Puerto Del Buceo   1.0         2      520000      520000
#
#                                                                                                                                                                                    Link
# 561  https://apartamento.mercadolibre.com.uy/MLU-657105296-apartamento-en-el-panamericano-_JM#position=33&search_layout=grid&type=item&tracking_id=a96e0c15-1ec1-40d8-97d6-15b2a48b602b

# %%
# Obtener barrio en funcion de una condicion del precio
df.loc[df['Precio Mt2'] == max(df['Precio Mt2']), 'Barrio']
# Out:
# 561    Puerto Buceo
# Name: Barrio, dtype: object

# %%
# Busqueda con mas de un filtro
filtro=df.loc[(df['Barrio'].str.contains('Punta Carretas')) & (df['Precio Mt2']< 3000)]
#print(len(filtro))
#print(filtro)
#df.loc[(df['Precio Mt2']< 2500)]

df.loc[(df['Barrio'].str.contains('Punta Carretas')) & (df['Precio Mt2']< 3000)]
# Out:
#                  Barrio           Direccion   Mts2  Nro Dorm  Precio USD  \
# 150  Punta Carretas,...   Rambla Gandhi 600  138.0         2      350000
# 271   Punta Carretas...  Solano Garcia 2432  154.0         2      358131
# 352      Punta Carretas      Roque Graseras  137.0         2      375000
# 436      Punta Carretas          Unidad 304  154.0         2      398131
# 456      Punta Carretas         Unidad 1001  168.0         2      499681
# 788      Punta Carretas        Ellauri 0000  125.0         2      299000
#
#      Precio Mt2  \
# 150        2536
# 271        2326
# 352        2737
# 436        2585
# 456        2974
# 788        2392
#
#                                                                                                                                                                                                                                                            Link
# 150                                     https://apartamento.mercadolibre.com.uy/MLU-658142578-apartamento-en-venta-de-2-dormitorios-en-punta-carretas-ref-jpd-1310-_JM#position=6&search_layout=grid&type=item&tracking_id=74c3faa2-895a-4b8c-9d95-3cd85cd2f67f
# 271                                                             https://apartamento.mercadolibre.com.uy/MLU-652686018-sky-punta-carretas-apartamentos-a-tu-altura-_JM#position=31&search_layout=grid&type=item&tracking_id=cbb522e0-858c-48eb-b376-cc5d194afbd9
# 352                                              https://apartamento.mercadolibre.com.uy/MLU-633552199-venta-apartamento-2-dormitorios-punta-carretas-con-cochera-_JM#position=16&search_layout=grid&type=item&tracking_id=9e932b03-7571-4bb2-8a54-a1f454e0f6e2
# 436                            https://apartamento.mercadolibre.com.uy/MLU-655396380-venta-apto-2-dormitorios-bano-en-suite-con-gran-terraza-garage-punta-carretas-_JM#position=4&search_layout=grid&type=item&tracking_id=9b53583d-d42c-4c13-8e74-90d79d97d8f8
# 456  https://apartamento.mercadolibre.com.uy/MLU-656974876-venta-penthouse-2-dormitorios-gran-terraza-al-frente-con-parrillero-exclusivo-2-garages-punta-carretas-_JM#position=24&search_layout=grid&type=item&tracking_id=9b53583d-d42c-4c13-8e74-90d79d97d8f8
# 788                                                                          https://apartamento.mercadolibre.com.uy/MLU-653129862-oferta-ultima-unidad-piso-alto-_JM#position=20&search_layout=grid&type=item&tracking_id=1e433c47-6192-46b2-a8e8-427fa8cb605b
